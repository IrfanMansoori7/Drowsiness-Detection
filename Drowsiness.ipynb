# %%
# Install OpenCV and any other dependencies
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Import the required libraries
import cv2
import numpy as np

# Open the webcam for video capture
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Webcam successfully opened.")
# Out:
# Webcam successfully opened.

# %%
# Display the webcam feed in a window
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break
    
    # Show the video frame
    cv2.imshow('Webcam Feed', frame)
    
    # Exit the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close the window
cap.release()
cv2.destroyAllWindows()

# %%
# Load pre-trained Haar cascades for face and eye detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Open the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Webcam successfully opened.")

# Detect face and eyes in the webcam feed
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break
    
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    
    for (x, y, w, h) in faces:
        # Draw rectangle around the face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        
        # Region of interest for face
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        
        # Detect eyes within the face region
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)
    
    # Show the video frame with face and eye detection
    cv2.imshow('Face and Eye Detection', frame)
    
    # Exit the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Webcam successfully opened.

# %%
# Load Haar cascades for face and eye detection (if not already loaded)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Open the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Webcam successfully opened.")

# Initialize variables for drowsiness detection
drowsiness_counter = 0
drowsiness_threshold = 30  # Number of frames eyes must be closed to trigger an alarm

# Drowsiness detection in the webcam feed
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)

        if len(eyes) == 0:  # No eyes detected (indicating closed eyes)
            drowsiness_counter += 1
            if drowsiness_counter >= drowsiness_threshold:
                cv2.putText(frame, "DROWSY!", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                # Here you can add alarm code (e.g., sound an alarm)
        else:
            drowsiness_counter = 0  # Reset counter if eyes are detected

        # Draw rectangles around eyes
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)

    cv2.imshow('Drowsiness Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Webcam successfully opened.

# %%
import cv2
import numpy as np

# Load Haar cascades for face and eye detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Open the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Webcam successfully opened.")

# Initialize variables for drowsiness detection
drowsiness_counter = 0
drowsiness_threshold = 30  # Number of frames eyes must be closed to trigger an alarm

# Drowsiness detection in the webcam feed
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    if len(faces) > 0:
        for (x, y, w, h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = frame[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)

            # Check if no eyes are detected
            if len(eyes) == 0:  # Eyes are likely closed
                drowsiness_counter += 1
                if drowsiness_counter >= drowsiness_threshold:
                    cv2.putText(frame, "DROWSY!", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
            else:
                drowsiness_counter = 0  # Reset counter if eyes are detected

            # Draw rectangles around eyes
            for (ex, ey, ew, eh) in eyes:
                cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)

    cv2.imshow('Drowsiness Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Webcam successfully opened.

# %%
import cv2

# Load Haar cascades for face and eye detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Open the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Webcam successfully opened.")

# Initialize variables for drowsiness detection
drowsiness_counter = 0
drowsiness_threshold = 30  # Number of frames eyes must be closed to trigger an alarm

# Drowsiness detection in the webcam feed
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    if len(faces) > 0:
        for (x, y, w, h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = frame[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)

            # Check for drowsiness
            if len(eyes) == 0:  # No eyes detected (indicating closed eyes)
                drowsiness_counter += 1
                if drowsiness_counter >= drowsiness_threshold:
                    cv2.putText(frame, "DROWSY!", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                    # Here you can add alarm code (e.g., sound an alarm)
            else:
                drowsiness_counter = 0  # Reset counter if eyes are detected

            # Draw rectangles around detected eyes
            for (ex, ey, ew, eh) in eyes:
                cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)

    cv2.imshow('Drowsiness Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Webcam successfully opened.

# %%
pip install playsound
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7043 sha256=429badc3da91a478e88aa09f073666e579d0257ea4e5e34c89b60df59e66b8cc
#   Stored in directory: c:\users\irfan\appdata\local\pip\cache\wheels\cf\42\ff\7c587bae55eec67b909ca316b250d9b4daedbf272a3cbeb907
# Successfully built playsound
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 325.1 kB/s eta 0:00:33
#    ---------------------------------------- 0.0/10.8 MB 325.1 kB/s eta 0:00:33
#    ---------------------------------------- 0.0/10.8 MB 325.1 kB/s eta 0:00:33
#    ---------------------------------------- 0.0/10.8 MB 325.1 kB/s eta 0:00:33
#    ---------------------------------------- 0.0/10.8 MB 325.1 kB/s eta 0:00:33
#    ---------------------------------------- 0.1/10.8 MB 291.5 kB/s eta 0:00:37
#    ---------------------------------------- 0.1/10.8 MB 281.0 kB/s eta 0:00:38
#    ---------------------------------------- 0.1/10.8 MB 300.4 kB/s eta 0:00:36
# ...

# %%
pip install simpleaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.0 MB 217.9 kB/s eta 0:00:10
#       --------------------------------------- 0.0/2.0 MB 281.8 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/2.0 MB 476.3 kB/s eta 0:00:05
#      ------ --------------------------------- 0.3/2.0 MB 1.5 MB/s eta 0:00:02
#      --------- ------------------------------ 0.5/2.0 MB 1.9 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.6/2.0 MB 1.8 MB/s eta 0:00:01
#      ------------ --------------------------- 0.6/2.0 MB 1.8 MB/s eta 0:00:01
# ...

# %%
import cv2
import time
import threading
import pygame

# Load the pre-trained Haar cascade for eye detection
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Initialize some parameters
eye_closed_frames = 0
drowsiness_threshold = 15  # Number of consecutive frames with eyes closed
alarm_sound = 'C:\\Users\\irfan\\alarm.mp3'  # Specify the correct path to your alarm sound

# Initialize pygame mixer
pygame.mixer.init()

# Function to play alarm sound
def play_alarm():
    pygame.mixer.music.load(alarm_sound)
    pygame.mixer.music.play(-1)  # Play sound on loop

# Function to stop the alarm
def stop_alarm():
    pygame.mixer.music.stop()

# Open webcam feed
cap = cv2.VideoCapture(0)
alarm_triggered = False  # Keep track of alarm status

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Resize the frame to make processing faster
    frame = cv2.resize(frame, (640, 480))
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect eyes
    eyes = eye_cascade.detectMultiScale(gray, 1.3, 5)

    if len(eyes) == 0:
        # If no eyes are detected, increase the counter
        eye_closed_frames += 1
        if eye_closed_frames >= drowsiness_threshold and not alarm_triggered:
            # Trigger alarm when the threshold is reached
            threading.Thread(target=play_alarm).start()
            alarm_triggered = True
    else:
        # Reset the counter and stop the alarm if eyes are open
        eye_closed_frames = 0
        if alarm_triggered:
            stop_alarm()
            alarm_triggered = False

    # Draw rectangles around detected eyes
    for (x, y, w, h) in eyes:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Drowsiness Detection', frame)

    # Break loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
